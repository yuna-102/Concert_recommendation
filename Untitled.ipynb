# %%
data=pd.read_excel('data/2018_공연시설별+통계목록.xls', header=3)
data=data.fillna(method='ffill')
data.columns=['시설명','공연홀','좌석수','공연건수','개막편수','상연횟수','예매수']

# %%
location=pd.read_excel('data/공연장등록현황_2018.xlsx',header=2)
location=location.loc[:,['시도별','시군구','시설명']]
location.dropna(axis=0, inplace=True)

# %%
location=pd.read_excel('./DB공연장.xls', header=3)

# %%
location=location.dropna(axis=0)

# %%
location=location.rename(columns={'시설명(링크)':'시설명','Unnamed: 9':'시군구'})
location=location.loc[:,['시설특성','지역','시군구','주소','시설명']]

# %%
df=pd.merge(data,location,on='시설명', how='inner')

# %%
df
# Out:
#           시설명      공연홀   좌석수  공연건수  개막편수  상연횟수     예매수       시설특성  지역  시군구  \
# 0       예술의전당     콘서트홀  2527   155   155   157  176839         국립  서울  서초구
# 1       예술의전당    오페라극장  2283    19    19    83   88155         국립  서울  서초구
# 2       예술의전당   IBK챔버홀   600   200   200   201   65978         국립  서울  서초구
# 3       예술의전당  CJ 토월극장  1004    15    15   189   55309         국립  서울  서초구
# 4       예술의전당    리사이틀홀   354   181   181   181   48292         국립  서울  서초구
# ...       ...      ...   ...   ...   ...   ...     ...        ...  ..  ...
# 1116   천마아트센터      챔버홀   510     0     0     0       0  민간(대학로 외)  경북  경산시
# 1117   천마아트센터       합계  2399     1     1     1       0  민간(대학로 외)  경북  경산시
# 1118  청춘나비아트홀       합계    80     1     1     1       0  민간(대학로 외)  부산  수영구
# 1119   최순우 옛집       합계    30     1     1     1       0   기타(비공연장)  서울  성북구
# 1120    해피씨어터       합계   219     2     1    67     -18    민간(대학로)  서울  종로구
#
#                                주소
# 0     서울특별시 서초구 남부순환로 2406 (서초동)
# ...

# %%
df.to_csv("stage_location.csv")

# %%
df=pd.read_csv('./stage_location.csv',index_col=0 )
df
# Out:
#           시설명      공연홀   좌석수  공연건수  개막편수  상연횟수     예매수       시설특성  지역  시군구  \
# 0       예술의전당     콘서트홀  2527   155   155   157  176839         국립  서울  서초구
# 1       예술의전당    오페라극장  2283    19    19    83   88155         국립  서울  서초구
# 2       예술의전당   IBK챔버홀   600   200   200   201   65978         국립  서울  서초구
# 3       예술의전당  CJ 토월극장  1004    15    15   189   55309         국립  서울  서초구
# 4       예술의전당    리사이틀홀   354   181   181   181   48292         국립  서울  서초구
# ...       ...      ...   ...   ...   ...   ...     ...        ...  ..  ...
# 1116   천마아트센터      챔버홀   510     0     0     0       0  민간(대학로 외)  경북  경산시
# 1117   천마아트센터       합계  2399     1     1     1       0  민간(대학로 외)  경북  경산시
# 1118  청춘나비아트홀       합계    80     1     1     1       0  민간(대학로 외)  부산  수영구
# 1119   최순우 옛집       합계    30     1     1     1       0   기타(비공연장)  서울  성북구
# 1120    해피씨어터       합계   219     2     1    67     -18    민간(대학로)  서울  종로구
#
#                                주소
# 0     서울특별시 서초구 남부순환로 2406 (서초동)
# ...

# %%
df.loc[df['지역'] == '서울',:]
# Out:
#               시설명      공연홀   좌석수  공연건수  개막편수  상연횟수     예매수       시설특성  지역  \
# 0           예술의전당     콘서트홀  2527   155   155   157  176839         국립  서울
# 1           예술의전당    오페라극장  2283    19    19    83   88155         국립  서울
# 2           예술의전당   IBK챔버홀   600   200   200   201   65978         국립  서울
# 3           예술의전당  CJ 토월극장  1004    15    15   189   55309         국립  서울
# 4           예술의전당    리사이틀홀   354   181   181   181   48292         국립  서울
# ...           ...      ...   ...   ...   ...   ...     ...        ...  ..
# 1107  경희대학교 평화의전당       합계  4500     1     1     2       0  민간(대학로 외)  서울
# 1111      마포중앙도서관       합계   396     1     1     1       0     공공(기타)  서울
# 1112   북쌔즈 복합문화공간       합계     0     1     1     1       0  민간(대학로 외)  서울
# 1119       최순우 옛집       합계    30     1     1     1       0   기타(비공연장)  서울
# 1120        해피씨어터       합계   219     2     1    67     -18    민간(대학로)  서울
#
#        시군구                            주소
# ...

# %%
df.groupby('지역')['좌석수'].sum()
# Out:
# 지역
# 강원     30302
# 경기    112192
# 경남     33954
# 경북     35614
# 광주     21174
# 대구     42736
# 대전     19643
# 부산     64029
# 서울    535946
# 세종      2520
# 울산     12436
# 인천     18651
# 전남     17300
# 전북     37230
# 제주     10473
# 충남     20103
# 충북     16931
# Name: 좌석수, dtype: int64

# %%
show=pd.read_excel('./DB검색_공연DB.xls', index_col=0,header=4, names = ['No','공연명','장르', '시작일','종료일','시설명','공연장','좌석수','제작'])

# %%
show
# Out:
#                       공연명   장르         시작일         종료일  \
# No
# 1     스크루지의 크리스마스 파티 [수원]  뮤지컬  2018.11.24  2019.01.01
# 2           공룡 애니멀쇼 [동두천]  뮤지컬  2018.12.01  2018.12.02
# 3         롯데콘서트홀 송년·제야음악회  클래식  2018.12.30  2018.12.31
# 4           노리야 학교가자 [수원]  뮤지컬  2018.10.20  2018.11.18
# 5      비보이를 사랑한 발레리나 [구미]  뮤지컬  2018.12.25  2018.12.25
# ...                   ...  ...         ...         ...
# 4472               쿵 페스티벌  뮤지컬  2012.04.17  2018.12.31
# 4473              극적인 하룻밤   연극  2014.09.26  2019.02.24
# 4474            작업의 정석 1탄   연극  2015.01.01         오픈런
# 4475     수상한 흥신소 1탄 [대학로]   연극  2015.03.01  2018.03.18
# 4476            페인터즈 [종로]  뮤지컬  2015.01.01         오픈런
#
#                                        시설명                     공연장    좌석수  \
# No
# 1                               KBS 수원아트홀                KBS 수원아트홀    200
# 2                                 동두천시민회관                  동두천시민회관    480
# ...

# %%
show[show['시설명'].str.contains('구미시문화예술회관')]
# Out:
#                    공연명   장르         시작일         종료일         시설명   공연장    좌석수  \
# No
# 5   비보이를 사랑한 발레리나 [구미]  뮤지컬  2018.12.25  2018.12.25  구미시문화예술회관   대공연장  1,211
#
#              제작
# No
# 5   (주)쇼봄(쇼비보이)

# %%
genre=show.groupby('시설명')['장르'].unique()

# %%
genre=genre.to_frame()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-102-ba3cd8c37181> in <module>
# ----> 1 genre=genre.to_frame()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'to_frame'

# %%
genre
# Out:
#                                      장르
# 시설명
# (재)경기문화재단                          [연극]
# (재)영화의전당                [오페라, 뮤지컬, 클래식]
# 2001 아울렛키즈홀 [수원남문]                [뮤지컬]
# 3.15아트센터             [클래식, 뮤지컬, 무용, 연극]
# 30스튜디오 (폐관)                        [연극]
# ...                                 ...
# 홍익대 대학로 아트센터                  [연극, 뮤지컬]
# 효로민락소극장                            [연극]
# 효천아트센터 그라운드씬                       [연극]
# 후용공연예술센터                           [연극]
# 흰물결아트센터                  [클래식, 뮤지컬, 무용]
#
# [611 rows x 1 columns]

# %%
from sklearn.preprocessing import MultiLabelBinarizer
s=genre['장르']
mlb = MultiLabelBinarizer()

genres=pd.DataFrame(mlb.fit_transform(s),columns=mlb.classes_, index=genre.index)

# %%
genres.reset_index(inplace=True)

# %%
genres.to_csv('genres.csv')

# %%
df
# Out:
#           시설명      공연홀   좌석수  공연건수  개막편수  상연횟수     예매수       시설특성  지역  시군구  \
# 0       예술의전당     콘서트홀  2527   155   155   157  176839         국립  서울  서초구
# 1       예술의전당    오페라극장  2283    19    19    83   88155         국립  서울  서초구
# 2       예술의전당   IBK챔버홀   600   200   200   201   65978         국립  서울  서초구
# 3       예술의전당  CJ 토월극장  1004    15    15   189   55309         국립  서울  서초구
# 4       예술의전당    리사이틀홀   354   181   181   181   48292         국립  서울  서초구
# ...       ...      ...   ...   ...   ...   ...     ...        ...  ..  ...
# 1116   천마아트센터      챔버홀   510     0     0     0       0  민간(대학로 외)  경북  경산시
# 1117   천마아트센터       합계  2399     1     1     1       0  민간(대학로 외)  경북  경산시
# 1118  청춘나비아트홀       합계    80     1     1     1       0  민간(대학로 외)  부산  수영구
# 1119   최순우 옛집       합계    30     1     1     1       0   기타(비공연장)  서울  성북구
# 1120    해피씨어터       합계   219     2     1    67     -18    민간(대학로)  서울  종로구
#
#                                주소
# 0     서울특별시 서초구 남부순환로 2406 (서초동)
# ...

# %%
df1=pd.merge(df,genres,on='시설명', how='inner')

# %%
df1
# Out:
#           시설명      공연홀   좌석수  공연건수  개막편수  상연횟수     예매수       시설특성  지역  시군구  \
# 0       예술의전당     콘서트홀  2527   155   155   157  176839         국립  서울  서초구
# 1       예술의전당    오페라극장  2283    19    19    83   88155         국립  서울  서초구
# 2       예술의전당   IBK챔버홀   600   200   200   201   65978         국립  서울  서초구
# 3       예술의전당  CJ 토월극장  1004    15    15   189   55309         국립  서울  서초구
# 4       예술의전당    리사이틀홀   354   181   181   181   48292         국립  서울  서초구
# ...       ...      ...   ...   ...   ...   ...     ...        ...  ..  ...
# 1099   천마아트센터      챔버홀   510     0     0     0       0  민간(대학로 외)  경북  경산시
# 1100   천마아트센터       합계  2399     1     1     1       0  민간(대학로 외)  경북  경산시
# 1101  청춘나비아트홀       합계    80     1     1     1       0  민간(대학로 외)  부산  수영구
# 1102   최순우 옛집       합계    30     1     1     1       0   기타(비공연장)  서울  성북구
# 1103    해피씨어터       합계   219     2     1    67     -18    민간(대학로)  서울  종로구
#
#                                주소 국악 무용 뮤지컬 복합 연극 오페라 클래식
# ...

# %%
genres=genres.astype(str).stack().str.strip().unstack()
